# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
m_cycle = pd.read_csv('Sample_Sales_Data.csv')
m_cycle
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
m_cycle.ORDERNUMBER.isna().value_counts()
# Out:
# False    2823
# Name: ORDERNUMBER, dtype: int64

# %%
m_cycle["ORDERNUMBER"].value_counts()
# Out:
# 10332    18
# 10106    18
# 10159    18
# 10168    18
# 10398    18
#          ..
# 10242     1
# 10189     1
# 10286     1
# 10216     1
# 10294     1
# Name: ORDERNUMBER, Length: 307, dtype: int64

# %%
m_cycle[m_cycle["ORDERNUMBER"] == 10332].head(20)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 494         10332               46      95.13               15  4375.98
# 520         10332               27      89.89               16  2427.03
# 696         10332               38      84.25                9  3201.50
# 745         10332               35      64.69                8  2264.15
# 849         10332               24      52.67                1  1264.08
# 928         10332               26     100.00               17  2979.08
# 981         10332               40      39.80               18  1592.00
# 1283        10332               50     100.00                2  7310.00
# 1409        10332               21     100.00                3  3472.98
# 1432        10332               23      56.84                4  1307.32
# 1510        10332               20      87.96                5  1759.20
# 1556        10332               45      81.91                6  3685.95
# ...

# %%
m_cycle[m_cycle["ORDERNUMBER"] == 10332]["PRODUCTCODE"].head(20)
# Out:
# 494     S18_1342
# 520     S18_1367
# 696     S18_2248
# 745     S18_2325
# 849     S18_2795
# 928     S18_2957
# 981     S18_3136
# 1283    S18_4409
# 1409    S18_4933
# 1432    S24_1046
# 1510    S24_1628
# 1556    S24_1937
# 1634    S24_2022
# 1710    S24_2766
# 1786    S24_2887
# 1862    S24_3191
# 1938    S24_3432
# 2040    S24_3969
# Name: PRODUCTCODE, dtype: object

# %%
m_cycle[m_cycle["ORDERNUMBER"] == 10332]["PRODUCTCODE"].head(20).value_counts()
# Out:
# S18_1342    1
# S18_1367    1
# S24_3432    1
# S24_3191    1
# S24_2887    1
# S24_2766    1
# S24_2022    1
# S24_1937    1
# S24_1628    1
# S24_1046    1
# S18_4933    1
# S18_4409    1
# S18_3136    1
# S18_2957    1
# S18_2795    1
# S18_2325    1
# S18_2248    1
# S24_3969    1
# Name: PRODUCTCODE, dtype: int64

# %%
m_cycle[m_cycle["ORDERNUMBER"] == 10332]["PRODUCTCODE"].head(20).value_counts().sum()
# Out:
# 18

# %% [markdown]
# ## So every individual product ordered has own listing. Can share order # is more than 1 product is ordered at a time
#
#
# # Cuts
#
# ## All sales are date only - hours and seconds can be cut
# ## Actually have col of quarters and months and years? Combine into new simple column and cut month and year col
#
# ## Maybe want to cut any canceled/ removed sales?
# ## Cut on hold? Resolved? Disputed?
# ## Look At who canceled most
# ##

# %% [markdown]
# # Investigate
#
#
# ## Highest profit product line by year
# ##
#
# ## Next lets look at correlations with time
# ## Each product line's performance over time
# ## Industry that bought most over time(buyer vs sales)
# ## best sales over time per product line
# ## Regions over time (sales vs region)
# ## SALES VS COUNTRY
# ## Sales vs state
# ## vs city
# ## VS
#
#
# ## Best customers (buyer vs sales)
#
# ## Look at highest volume sales and best contact?
# ## look at hiest volume sales and highest profit sales companies and contacts
#
#
# ## Best product per country
# ## best line per country/city /state/region
# ## most profitable product
# ## Best selling product
# ## Best seller by region/city/country/state

# %% [markdown]
# # Correlation MAPS WITH HEAT
# # See where things may be best

# %%
m_cycle
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
m_cycle.corr()
# Out:
#                  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# ORDERNUMBER         1.000000         0.065543  -0.002935        -0.055550
# QUANTITYORDERED     0.065543         1.000000   0.005564        -0.018397
# PRICEEACH          -0.002935         0.005564   1.000000        -0.020965
# ORDERLINENUMBER    -0.055550        -0.018397  -0.020965         1.000000
# SALES               0.039919         0.551426   0.657841        -0.058400
# QTR_ID             -0.051383        -0.035323   0.008712         0.040716
# MONTH_ID           -0.039723        -0.039048   0.005152         0.034016
# YEAR_ID             0.904596         0.069535  -0.005938        -0.057367
# MSRP               -0.010280         0.017881   0.670625        -0.021067
#
#                     SALES    QTR_ID  MONTH_ID   YEAR_ID      MSRP
# ORDERNUMBER      0.039919 -0.051383 -0.039723  0.904596 -0.010280
# QUANTITYORDERED  0.551426 -0.035323 -0.039048  0.069535  0.017881
# ...

# %%
plt.figure(figsize=(14, 12))


heatmap = sns.heatmap(m_cycle.corr(), annot=True)

# %%
m_cycle.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# Pairplot

# %%
# We will reduce the metrics to those of interest and those that have been engineered

#creating a list of our metrics of interest
metrics_list = ['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
       'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
       'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
       'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
       'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
       'DEALSIZE']
p_plot = m_cycle[metrics_list]


sns.pairplot(p_plot);

# %% [markdown]
# Next do lin regs

# %% [markdown]
# PLACEHOLDER GRAPH

# %%
fig, ax = plt.subplots(figsize = (20,10))
x = m_cycle["SALES"]
y = m_cycle["QUANTITYORDERED"]
ax.bar(x,y)
plt.xticks(fontsize = 15, rotation = 65)
ax.set_xlabel("X", fontsize = 20)
ax.set_ylabel("Y", fontsize = 20)
ax.set_title("Title", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Title')

# %%
m_cycle.ORDERNUMBER.isna().value_counts()
